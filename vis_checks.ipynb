# %%
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.windows import Window
from pyproj import CRS, Transformer
import plotly.graph_objects as go
import plotly.io as pio
import spiceypy as spice
from scenarios import *
import trimesh
pio.renderers.default = 'browser'

# %%
mesh, pos_tx, pos_rx, boresight_tx, boresight_rx, sep = choose_scenario("lunar")

visualize_mesh_3D(mesh, pos_tx, pos_rx, size = 3, show_axes=True, show_edges=True, vis_map=True)
# Out:
# Griglia (terrain): 1/1 nodi generati (n=1, spacing=30m, area=0x0m)
# [TX visibility map] Not reachable: 302/20000 (1.5%)
